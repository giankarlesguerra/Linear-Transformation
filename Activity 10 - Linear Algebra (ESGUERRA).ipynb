# %% [markdown]
# # <b>Linear Algebra for CpE

# %% [markdown]
# ## Laboratory 10 : Linear Transformations

# %% [markdown]
# <h5>Coded and Submitted by:
# <h5><i>Esguerra, Gian Karl J.<i>
# <h5><i>2018113661<i>
# <h5><i>58011<i>

# %% [markdown]
# ## Supplementary Activity

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a grid of points in x-y space 

x_axis = np.linspace(-5, 4, 9)
y_axis = np.linspace(-5, 3, 7)
xy_grid = np.column_stack([[x, y] for x in xvals for y in yvals])
# Plot grid points 

plt.figure(figsize=(5, 5), facecolor="w")
plt.scatter(xygrid[0], xygrid[1], s=36, c="green", edgecolor="none")
plt.grid(True)
plt.axis("equal")

#ROTATION

theta = np.pi/3 
B = np.column_stack([[np.cos(theta), np.sin(theta)], [-np.sin(theta), np.cos(theta)]])
print(B)

uvgrid2 = np.dot(B, xygrid)

plt.figure(figsize=(5, 5), facecolor="w")
plt.scatter(uvgrid2[0], uvgrid2[1], s=36, c="green", edgecolor="none")
plt.grid(True)
plt.axis("equal")
# Out:
# [[ 0.5       -0.8660254]
#  [ 0.8660254  0.5      ]]
# (-5.669486372867091, 6.901537180435968, -7.41983845062519, 5.5538130468407525)
